# %% [markdown]
# #Taller importación y extracción de datos
# ###Juan Esteban Barrantes
# ###Juan Camilo Ordoñez
# ###Daniel Alejandro Caicedo

# %% [markdown]
# ####Librerias requeridas

# %%
# !pip install xlrd openpyxl
# !pip install pandas
# !pip install wbdata

# %%
import pandas as pd
import numpy as np
import wbdata
import datetime
import os
import requests

# %% [markdown]
# ##Primer punto

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= '/content/drive/MyDrive/Dataset'

# %%
os.chdir(path)

# %%
df_mun_drive = pd.read_csv('/content/drive/MyDrive/Dataset/dataset_2026-03-05T13_12_12.035043298Z_DEFAULT_INTEGRATION_IMF.RES_WEO_9.0.0.csv', sep=",", decimal='.', encoding ='utf-8', converters={'Cod. Municipio':str})
df_mun_drive.head()
# Out:
# /tmp/ipykernel_722/3434495009.py:1: DtypeWarning: Columns (9,14,15,17,51,53,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mun_drive = pd.read_csv('/content/drive/MyDrive/Dataset/dataset_2026-03-05T13_12_12.035043298Z_DEFAULT_INTEGRATION_IMF.RES_WEO_9.0.0.csv', sep=",", decimal='.', encoding ='utf-8', converters={'Cod. Municipio':str})
#               DATASET   SERIES_CODE OBS_MEASURE  \
# 0  IMF.RES:WEO(9.0.0)      LIE.LE.A   OBS_VALUE
# 1  IMF.RES:WEO(9.0.0)      CAN.LE.A   OBS_VALUE
# 2  IMF.RES:WEO(9.0.0)  HND.NGDPPC.A   OBS_VALUE
# 3  IMF.RES:WEO(9.0.0)      HND.LP.A   OBS_VALUE
# 4  IMF.RES:WEO(9.0.0)      BHS.LP.A   OBS_VALUE
#
#                           COUNTRY  \
# 0  Liechtenstein, Principality of
# 1                          Canada
# 2                        Honduras
# 3                        Honduras
# 4                    Bahamas, The
#
#                                            INDICATOR FREQUENCY     SCALE  \
# ...

# %%
#primeras 5 filas
df_mun_drive.head()
# Out:
#               DATASET   SERIES_CODE OBS_MEASURE  \
# 0  IMF.RES:WEO(9.0.0)      LIE.LE.A   OBS_VALUE
# 1  IMF.RES:WEO(9.0.0)      CAN.LE.A   OBS_VALUE
# 2  IMF.RES:WEO(9.0.0)  HND.NGDPPC.A   OBS_VALUE
# 3  IMF.RES:WEO(9.0.0)      HND.LP.A   OBS_VALUE
# 4  IMF.RES:WEO(9.0.0)      BHS.LP.A   OBS_VALUE
#
#                           COUNTRY  \
# 0  Liechtenstein, Principality of
# 1                          Canada
# 2                        Honduras
# 3                        Honduras
# 4                    Bahamas, The
#
#                                            INDICATOR FREQUENCY     SCALE  \
# 0  Employed persons, Persons for countries / Inde...    Annual  Millions
# 1  Employed persons, Persons for countries / Inde...    Annual  Millions
# 2  Gross domestic product (GDP), Current prices, ...    Annual     Units
# 3  Population, Persons for countries / Index for ...    Annual  Millions
# 4  Population, Persons for countries / Index for ...    Annual  Millions
#
# ...

# %%
#1ultimas 10 filas
df_mun_drive.tail(10)
# Out:
#                  DATASET         SERIES_CODE OBS_MEASURE  \
# 8198  IMF.RES:WEO(9.0.0)       TKM.TX_RPCH.A   OBS_VALUE
# 8199  IMF.RES:WEO(9.0.0)        UZB.NGDP_D.A   OBS_VALUE
# 8200  IMF.RES:WEO(9.0.0)   MOZ.GGXWDG_NGDP.A   OBS_VALUE
# 8201  IMF.RES:WEO(9.0.0)        MOZ.GGXWDG.A   OBS_VALUE
# 8202  IMF.RES:WEO(9.0.0)  ZWE.GGXONLB_NGDP.A   OBS_VALUE
# 8203  IMF.RES:WEO(9.0.0)       ZWE.GGXONLB.A   OBS_VALUE
# 8204  IMF.RES:WEO(9.0.0)      ZWE.GGR_NGDP.A   OBS_VALUE
# 8205  IMF.RES:WEO(9.0.0)           ZWE.GGR.A   OBS_VALUE
# 8206  IMF.RES:WEO(9.0.0)        ZWE.GGXCNL.A   OBS_VALUE
# 8207  IMF.RES:WEO(9.0.0)   ZWE.GGXCNL_NGDP.A   OBS_VALUE
#
#                       COUNTRY  \
# 8198             Turkmenistan
# 8199  Uzbekistan, Republic of
# 8200  Mozambique, Republic of
# 8201  Mozambique, Republic of
# 8202                 Zimbabwe
# 8203                 Zimbabwe
# 8204                 Zimbabwe
# 8205                 Zimbabwe
# 8206                 Zimbabwe
# ...

# %%
#3 filas aleatoreas
df_mun_drive.sample(3)
# Out:
#                  DATASET   SERIES_CODE OBS_MEASURE          COUNTRY  \
# 6855  IMF.RES:WEO(9.0.0)     KGZ.BCA.A   OBS_VALUE  Kyrgyz Republic
# 2827  IMF.RES:WEO(9.0.0)   SUR.PPPSH.A   OBS_VALUE         Suriname
# 2608  IMF.RES:WEO(9.0.0)  PRI.NGDP_R.A   OBS_VALUE      Puerto Rico
#
#                                               INDICATOR FREQUENCY     SCALE  \
# 6855  Current account balance (credit less debit), U...    Annual  Billions
# 2827  Gross domestic product (GDP), Purchasing power...    Annual     Units
# 2608  Gross domestic product (GDP), Constant prices,...    Annual  Billions
#
#      DECIMALS_DISPLAYED  FUNCTIONAL_CAT             INT_ACC_ITEM  ...    2021  \
# 6855              Three             NaN  Current account balance  ...  -0.739
# 2827              Three             NaN                      NaN  ...   0.007
# 2608              Three             NaN                      NaN  ...  96.757
#
# ...

# %%
#de la fila 2 a la 5 y columna 2
df_mun_drive.iloc[1:5, 1]
# Out:
# 1        CAN.LE.A
# 2    HND.NGDPPC.A
# 3        HND.LP.A
# 4        BHS.LP.A
# Name: SERIES_CODE, dtype: object

# %%
#cuantas filas hay?
len(df_mun_drive)
# Out:
# 8208

# %%
#Numero de filas y columnas
df_mun_drive.shape
# Out:
# (8208, 116)

# %%
#nombres de las columnas
df_mun_drive.columns
# Out:
# Index(['DATASET', 'SERIES_CODE', 'OBS_MEASURE', 'COUNTRY', 'INDICATOR',
#        'FREQUENCY', 'SCALE', 'DECIMALS_DISPLAYED', 'FUNCTIONAL_CAT',
#        'INT_ACC_ITEM',
#        ...
#        '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029',
#        '2030'],
#       dtype='object', length=116)

# %%
#tipo de dato de cada columna
df_mun_drive.dtypes
# Out:
# DATASET         object
# SERIES_CODE     object
# OBS_MEASURE     object
# COUNTRY         object
# INDICATOR       object
#                 ...
# 2026           float64
# 2027           float64
# 2028           float64
# 2029           float64
# 2030           float64
# Length: 116, dtype: object

# %%
#informacion del dataset
df_mun_drive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8208 entries, 0 to 8207
# Columns: 116 entries, DATASET to 2030
# dtypes: float64(59), object(57)
# memory usage: 7.3+ MB

# %% [markdown]
# ##Segundo punto

# %%
indicador = {"FP.CPI.TOTL.ZG": "Inflación (%)"}
fecha_inicio = datetime.datetime(2010, 1, 1)
fecha_fin = datetime.datetime(2023, 1, 1)
paises = ["COL","ECU","BRA","CHL","MEX","PER"]
df_2 = wbdata.get_dataframe(indicador, country=paises, date=(fecha_inicio, fecha_fin))
df_2
# Out:
#               Inflación (%)
# country date
# Brazil  2023       4.593563
#         2022       9.280106
#         2021       8.301660
#         2020       3.211768
#         2019       3.732976
# ...                     ...
# Peru    2014       3.411946
#         2013       2.767897
#         2012       3.611213
#         2011       3.369311
#         2010       1.528321
#
# [84 rows x 1 columns]

# %%
#primeras 5 filas
df_2.head()
# Out:
#               Inflación (%)
# country date
# Brazil  2023       4.593563
#         2022       9.280106
#         2021       8.301660
#         2020       3.211768
#         2019       3.732976

# %%
#ultimas 10 filas
df_2.tail(10)
# Out:
#               Inflación (%)
# country date
# Peru    2019       2.252122
#         2018       1.509154
#         2017       2.994900
#         2016       3.557177
#         2015       3.398092
#         2014       3.411946
#         2013       2.767897
#         2012       3.611213
#         2011       3.369311
#         2010       1.528321

# %%
#3 filas aleatoreas
df_2.sample(3)
# Out:
#               Inflación (%)
# country date
# Chile   2023       7.581683
#         2011       3.341217
# Mexico  2012       4.111510

# %%
#de la fila 2 a la 5 y la segunda columna
df_2.iloc[1:5, 0]
# Out:
# country  date
# Brazil   2022    9.280106
#          2021    8.301660
#          2020    3.211768
#          2019    3.732976
# Name: Inflación (%), dtype: float64

# %%
#cuantas filas hay?
len(df_2)
# Out:
# 84

# %%
#cuantas filas y columnas hay?
df_2.shape
# Out:
# (84, 1)

# %%
#nombres de las columnas
df_2.columns
# Out:
# Index(['Inflación (%)'], dtype='object')

# %%
#tipo de dato
df_2.dtypes
# Out:
# Inflación (%)    float64
# dtype: object

# %%
#informacion del dataset
df_2.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# MultiIndex: 84 entries, ('Brazil', '2023') to ('Peru', '2010')
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Inflación (%)  84 non-null     float64
# dtypes: float64(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ##Tercer punto

# %%
indicador = {"NY.GDP.MKTP.KD.ZG": "Crecimiento PIB (%)",
    "NY.GDP.PCAP.PP.KD": "PIB per cápita PPA",
    "FP.CPI.TOTL.ZG": "Inflación (%)",
    "SL.UEM.TOTL.ZS": "Desempleo (%)",
    "SP.POP.TOTL": "Población"}

fecha_inicio = datetime.datetime(2010, 1, 1)
fecha_fin = datetime.datetime(2023, 1, 1)

paises = ["DEU"]

df_3 = wbdata.get_dataframe(indicador, country=paises, date=(fecha_inicio, fecha_fin))

df_3
# Out:
#       Crecimiento PIB (%)  PIB per cápita PPA  Inflación (%)  Desempleo (%)  \
# date
# 2023            -0.869648        63039.371970       5.946437          3.071
# 2022             1.809258        63676.087822       6.872574          3.137
# 2021             3.910000        62530.765320       3.066667          3.594
# 2020            -4.131914        60203.289760       0.144878          3.881
# 2019             0.977735        62849.374187       1.445660          3.163
# 2018             1.135696        62381.347877       1.732169          3.384
# 2017             2.797907        61866.487221       1.509495          3.781
# 2016             2.222222        60407.971370       0.491747          4.104
# 2015             1.663006        59573.708954       0.514426          4.612
# 2014             2.180186        59108.697729       0.906794          4.979
# 2013             0.396996        58089.170854       1.504723          5.316
# ...

# %%
#primeras 5 filas
df_3.head()
# Out:
#       Crecimiento PIB (%)  PIB per cápita PPA  Inflación (%)  Desempleo (%)  \
# date
# 2023            -0.869648        63039.371970       5.946437          3.071
# 2022             1.809258        63676.087822       6.872574          3.137
# 2021             3.910000        62530.765320       3.066667          3.594
# 2020            -4.131914        60203.289760       0.144878          3.881
# 2019             0.977735        62849.374187       1.445660          3.163
#
#        Población
# date
# 2023  83287273.0
# 2022  83177813.0
# 2021  83196078.0
# 2020  83160871.0
# 2019  83092962.0

# %%
#ultimas 10 filas
df_3.tail(10)
# Out:
#       Crecimiento PIB (%)  PIB per cápita PPA  Inflación (%)  Desempleo (%)  \
# date
# 2019             0.977735        62849.374187       1.445660          3.163
# 2018             1.135696        62381.347877       1.732169          3.384
# 2017             2.797907        61866.487221       1.509495          3.781
# 2016             2.222222        60407.971370       0.491747          4.104
# 2015             1.663006        59573.708954       0.514426          4.612
# 2014             2.180186        59108.697729       0.906794          4.979
# 2013             0.396996        58089.170854       1.504723          5.316
# 2012             0.463512        58017.585578       2.008489          5.372
# 2011             3.757969        57858.422260       2.075173          5.967
# 2010             4.134638        54738.708301       1.103810          7.043
#
#        Población
# date
# 2019  83092962.0
# 2018  82905782.0
# 2017  82657002.0
# 2016  82348669.0
# 2015  81686611.0
# ...

# %%
#3 filas aleatoreas
df_3.sample(3)
# Out:
#       Crecimiento PIB (%)  PIB per cápita PPA  Inflación (%)  Desempleo (%)  \
# date
# 2022             1.809258        63676.087822       6.872574          3.137
# 2023            -0.869648        63039.371970       5.946437          3.071
# 2016             2.222222        60407.971370       0.491747          4.104
#
#        Población
# date
# 2022  83177813.0
# 2023  83287273.0
# 2016  82348669.0

# %%
#de la fila 2 a la 5 y la segunda columna
df_3.iloc[1:5, 1]
# Out:
# date
# 2022    63676.087822
# 2021    62530.765320
# 2020    60203.289760
# 2019    62849.374187
# Name: PIB per cápita PPA, dtype: float64

# %%
#cuantas filas hay?
len(df_3)
# Out:
# 14

# %%
#cuantas filas y columnas hay?
df_3.shape
# Out:
# (14, 5)

# %%
#nombres de las columnas
df_3.columns
# Out:
# Index(['Crecimiento PIB (%)', 'PIB per cápita PPA', 'Inflación (%)',
#        'Desempleo (%)', 'Población'],
#       dtype='object')

# %%
#tipo de dato de la columna
df_3.dtypes
# Out:
# Crecimiento PIB (%)    float64
# PIB per cápita PPA     float64
# Inflación (%)          float64
# Desempleo (%)          float64
# Población              float64
# dtype: object

# %%
#informacion del dataset
df_3.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# Index: 14 entries, 2023 to 2010
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Crecimiento PIB (%)  14 non-null     float64
#  1   PIB per cápita PPA   14 non-null     float64
#  2   Inflación (%)        14 non-null     float64
#  3   Desempleo (%)        14 non-null     float64
#  4   Población            14 non-null     float64
# dtypes: float64(5)
# memory usage: 1.2+ KB

# %% [markdown]
# ##Cuarto punto

# %%
#Delitos en colombia
url1 = "https://www.datos.gov.co/resource/gt2j-8ykr.csv"
df_col_1 = pd.read_csv(url1)
df_col_1.head()
# Out:
#      fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 0  2020-12-24 00:00:00     1556979   2020-12-22 00:00:00            76
# 1  2020-12-24 00:00:00     1556980   2020-12-19 00:00:00            76
# 2  2020-12-24 00:00:00     1556981   2020-12-19 00:00:00            76
# 3  2020-12-24 00:00:00     1556982   2020-12-22 00:00:00            76
# 4  2020-12-24 00:00:00     1556983   2020-12-22 00:00:00            76
#
#   departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# 0            VALLE             76001                 CALI    67
# 1            VALLE             76001                 CALI    66
# 2            VALLE             76001                 CALI    68
# 3            VALLE             76001                 CALI    74
# 4            VALLE             76001                 CALI    65
#
#    unidad_medida sexo  ... pais_viajo_1_cod pais_viajo_1_nom  recuperado  \
# 0              1    F  ...              NaN              NaN  Recuperado
# ...

# %%
#primeras 5 filas
df_col_1.head()
# Out:
#      fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 0  2020-12-24 00:00:00     1556979   2020-12-22 00:00:00            76
# 1  2020-12-24 00:00:00     1556980   2020-12-19 00:00:00            76
# 2  2020-12-24 00:00:00     1556981   2020-12-19 00:00:00            76
# 3  2020-12-24 00:00:00     1556982   2020-12-22 00:00:00            76
# 4  2020-12-24 00:00:00     1556983   2020-12-22 00:00:00            76
#
#   departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# 0            VALLE             76001                 CALI    67
# 1            VALLE             76001                 CALI    66
# 2            VALLE             76001                 CALI    68
# 3            VALLE             76001                 CALI    74
# 4            VALLE             76001                 CALI    65
#
#    unidad_medida sexo  ... pais_viajo_1_cod pais_viajo_1_nom  recuperado  \
# 0              1    F  ...              NaN              NaN  Recuperado
# ...

# %%
#ultimas 10 filas
df_col_1.tail(10)
# Out:
#        fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 990  2020-09-03 00:00:00      640268   2020-08-13 00:00:00            68
# 991  2020-09-03 00:00:00      640269   2020-08-14 00:00:00            68
# 992  2020-09-03 00:00:00      640270   2020-08-11 00:00:00             5
# 993  2020-09-03 00:00:00      640271   2020-08-12 00:00:00            68
# 994  2020-09-03 00:00:00      640272   2020-08-14 00:00:00            68
# 995  2020-09-03 00:00:00      640273   2020-08-11 00:00:00             5
# 996  2020-09-03 00:00:00      640274   2020-08-13 00:00:00            68
# 997  2020-09-03 00:00:00      640275   2020-08-13 00:00:00            68
# 998  2020-09-03 00:00:00      640276   2020-08-13 00:00:00            68
# 999  2020-09-03 00:00:00      640277   2020-08-14 00:00:00             5
#
#     departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# 990        SANTANDER             68307                GIRON    23
# ...

# %%
#3 filas aleatoreas
df_col_1.sample(3)
# Out:
#        fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 214  2021-01-14 00:00:00     1841915   2021-01-12 00:00:00            11
# 49   2020-12-24 00:00:00     1556943   2020-12-19 00:00:00            76
# 337  2020-07-25 00:00:00      238797   2020-07-11 00:00:00            11
#
#     departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# 214           BOGOTA             11001               BOGOTA    53
# 49             VALLE             76001                 CALI    63
# 337           BOGOTA             11001               BOGOTA    50
#
#      unidad_medida sexo  ... pais_viajo_1_cod pais_viajo_1_nom  recuperado  \
# 214              1    M  ...              NaN              NaN  Recuperado
# 49               1    F  ...              NaN              NaN   Fallecido
# 337              1    M  ...              NaN              NaN  Recuperado
#
#      fecha_inicio_sintomas         fecha_muerte    fecha_diagnostico  \
# ...

# %%
#de la fila 2 a la 5 y la columna 2
df_col_1.iloc[1:5, 1]
# Out:
# 1    1556980
# 2    1556981
# 3    1556982
# 4    1556983
# Name: id_de_caso, dtype: int64

# %%
#cuantas filas hay?
len(df_col_1)
# Out:
# 1000

# %%
#cuantas filas y columnas hay?
df_col_1.shape
# Out:
# (1000, 23)

# %%
#nombres de las columnas
df_col_1.columns
# Out:
# Index(['fecha_reporte_web', 'id_de_caso', 'fecha_de_notificaci_n',
#        'departamento', 'departamento_nom', 'ciudad_municipio',
#        'ciudad_municipio_nom', 'edad', 'unidad_medida', 'sexo',
#        'fuente_tipo_contagio', 'ubicacion', 'estado', 'pais_viajo_1_cod',
#        'pais_viajo_1_nom', 'recuperado', 'fecha_inicio_sintomas',
#        'fecha_muerte', 'fecha_diagnostico', 'fecha_recuperado',
#        'tipo_recuperacion', 'per_etn_', 'nom_grupo_'],
#       dtype='object')

# %%
#tipo de dato de cada columna
df_col_1.dtypes
# Out:
# fecha_reporte_web         object
# id_de_caso                 int64
# fecha_de_notificaci_n     object
# departamento               int64
# departamento_nom          object
# ciudad_municipio           int64
# ciudad_municipio_nom      object
# edad                       int64
# unidad_medida              int64
# sexo                      object
# fuente_tipo_contagio      object
# ubicacion                 object
# estado                    object
# pais_viajo_1_cod         float64
# pais_viajo_1_nom         float64
# recuperado                object
# fecha_inicio_sintomas     object
# fecha_muerte              object
# fecha_diagnostico         object
# fecha_recuperado          object
# tipo_recuperacion         object
# per_etn_                   int64
# nom_grupo_                object
# dtype: object

# %%
#informacion del dataset
df_col_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_reporte_web      1000 non-null   object
#  1   id_de_caso             1000 non-null   int64
#  2   fecha_de_notificaci_n  1000 non-null   object
#  3   departamento           1000 non-null   int64
#  4   departamento_nom       1000 non-null   object
#  5   ciudad_municipio       1000 non-null   int64
#  6   ciudad_municipio_nom   1000 non-null   object
#  7   edad                   1000 non-null   int64
#  8   unidad_medida          1000 non-null   int64
#  9   sexo                   1000 non-null   object
#  10  fuente_tipo_contagio   1000 non-null   object
#  11  ubicacion              994 non-null    object
#  12  estado                 994 non-null    object
#  13  pais_viajo_1_cod       0 non-null      float64
# ...

# %%
#Accidentes de transito
url2 = "https://www.datos.gov.co/resource/72sg-cybi.csv"
df_col_2 = pd.read_csv(url2)
df_col_2.head()
# Out:
#    departamento           municipio  codigo_dane armas_medios fecha_hecho  \
# 0     ANTIOQUIA  Santa Rosa de Osos      5686000     VEHICULO  29/01/2023
# 1  CUNDINAMARCA    Bogotá D.C. (CT)     11001000     VEHICULO  29/01/2023
# 2     ANTIOQUIA          Campamento      5134000     VEHICULO  29/01/2023
# 3  CUNDINAMARCA    Bogotá D.C. (CT)     11001000     VEHICULO  25/01/2023
# 4        BOYACÁ        Chiquinquirá     15176000     VEHICULO  29/01/2023
#
#       genero grupo_etario                               descripci_n_conducta  \
# 0  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 1  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 2  MASCULINO      MENORES  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 3   FEMENINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 4  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
#
#    cantidad
# 0         2
# 1         1
# 2         2
# ...

# %%
#primeras 5 filas
df_col_2.head()
# Out:
#    departamento           municipio  codigo_dane armas_medios fecha_hecho  \
# 0     ANTIOQUIA  Santa Rosa de Osos      5686000     VEHICULO  29/01/2023
# 1  CUNDINAMARCA    Bogotá D.C. (CT)     11001000     VEHICULO  29/01/2023
# 2     ANTIOQUIA          Campamento      5134000     VEHICULO  29/01/2023
# 3  CUNDINAMARCA    Bogotá D.C. (CT)     11001000     VEHICULO  25/01/2023
# 4        BOYACÁ        Chiquinquirá     15176000     VEHICULO  29/01/2023
#
#       genero grupo_etario                               descripci_n_conducta  \
# 0  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 1  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 2  MASCULINO      MENORES  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 3   FEMENINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
# 4  MASCULINO      ADULTOS  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...
#
#    cantidad
# 0         2
# 1         1
# 2         2
# ...

# %%
#ultimas 10 filas
df_col_2.tail(10)
# Out:
#      departamento     municipio  codigo_dane armas_medios fecha_hecho  \
# 990         HUILA        Garzón     41298000     VEHICULO  02/04/2023
# 991         VALLE         Tuluá     76834000     VEHICULO  02/04/2023
# 992         HUILA        Garzón     41298000     VEHICULO  02/04/2023
# 993         CAUCA       Caldono     19137000     VEHICULO  02/04/2023
# 994        BOYACÁ      Sogamoso     15759000     VEHICULO  02/04/2023
# 995        BOYACÁ         Paipa     15516000     VEHICULO  02/04/2023
# 996  CUNDINAMARCA    Fusagasugá     25290000     VEHICULO  01/04/2023
# 997        BOYACÁ  Ventaquemada     15861000     VEHICULO  31/03/2023
# 998        BOYACÁ  Ventaquemada     15861000     VEHICULO  31/03/2023
# 999         HUILA    Neiva (CT)     41001000     VEHICULO  27/03/2023
#
#         genero grupo_etario  \
# 990  MASCULINO      ADULTOS
# 991   FEMENINO      ADULTOS
# 992   FEMENINO      ADULTOS
# 993   FEMENINO      ADULTOS
# 994   FEMENINO      ADULTOS
# ...

# %%
#3 filas aleatoras
df_col_2.sample(3)
# Out:
#      departamento           municipio  codigo_dane armas_medios fecha_hecho  \
# 911  CUNDINAMARCA    Bogotá D.C. (CT)     11001000     VEHICULO  28/03/2023
# 714          META  Villavicencio (CT)     50001000     VEHICULO  14/03/2023
# 966          META  Villavicencio (CT)     50001000     VEHICULO  29/03/2023
#
#         genero grupo_etario  \
# 911  MASCULINO      ADULTOS
# 714  MASCULINO      ADULTOS
# 966   FEMENINO      ADULTOS
#
#                                   descripci_n_conducta  cantidad
# 911  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...         3
# 714  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...         5
# 966  ARTÍCULO 120. LESIONES CULPOSAS ( EN ACCIDENTE...         1

# %%
# fila 2 a la 5 y la columna 2
df_col_2.iloc[1:5, 1]
# Out:
# 1    Bogotá D.C. (CT)
# 2          Campamento
# 3    Bogotá D.C. (CT)
# 4        Chiquinquirá
# Name: municipio, dtype: object

# %%
#cuantas filas hay?
len(df_col_2)
# Out:
# 1000

# %%
#cuantas filas y columnas hay?
df_col_2.shape
# Out:
# (1000, 9)

# %%
#cual es el nombre de las columnas
df_col_2.columns
# Out:
# Index(['departamento', 'municipio', 'codigo_dane', 'armas_medios',
#        'fecha_hecho', 'genero', 'grupo_etario', 'descripci_n_conducta',
#        'cantidad'],
#       dtype='object')

# %%
#tipo de dato de la columna
df_col_2.dtypes
# Out:
# departamento            object
# municipio               object
# codigo_dane              int64
# armas_medios            object
# fecha_hecho             object
# genero                  object
# grupo_etario            object
# descripci_n_conducta    object
# cantidad                 int64
# dtype: object

# %%
#informacion del dataset
df_col_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   departamento          1000 non-null   object
#  1   municipio             1000 non-null   object
#  2   codigo_dane           1000 non-null   int64
#  3   armas_medios          1000 non-null   object
#  4   fecha_hecho           1000 non-null   object
#  5   genero                999 non-null    object
#  6   grupo_etario          1000 non-null   object
#  7   descripci_n_conducta  1000 non-null   object
#  8   cantidad              1000 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %% [markdown]
# ## Quinto punto

# %%
url = "http://universities.hipolabs.com/search?country=Colombia"
data = requests.get(url).json()
df_uni = pd.DataFrame(data)
df_uni
# Out:
#     state-province   country                            web_pages  \
# 0             None  Colombia        [http://www.autonoma.edu.co/]
# 1             None  Colombia     [http://www.bellasartes.edu.co/]
# 2             None  Colombia  [http://www.bundenet.com/umusical/]
# 3             None  Colombia            [http://www.cesa.edu.co/]
# 4             None  Colombia             [http://www.ces.edu.co/]
# ..             ...       ...                                  ...
# 98            None  Colombia            [http://www.utch.edu.co/]
# 99            None  Colombia              [http://www.ut.edu.co/]
# 100           None  Colombia             [http://www.utp.edu.co/]
# 101           None  Colombia     [https://universidadean.edu.co/]
# 102           None  Colombia       [https://www.colmayor.edu.co/]
#
#                      domains alpha_two_code  \
# 0          [autonoma.edu.co]             CO
# 1       [bellasartes.edu.co]             CO
# ...

# %%
#primeras 5 filas
df_uni.head()
# Out:
#   state-province   country                            web_pages  \
# 0           None  Colombia        [http://www.autonoma.edu.co/]
# 1           None  Colombia     [http://www.bellasartes.edu.co/]
# 2           None  Colombia  [http://www.bundenet.com/umusical/]
# 3           None  Colombia            [http://www.cesa.edu.co/]
# 4           None  Colombia             [http://www.ces.edu.co/]
#
#                 domains alpha_two_code  \
# 0     [autonoma.edu.co]             CO
# 1  [bellasartes.edu.co]             CO
# 2        [bundenet.com]             CO
# 3         [cesa.edu.co]             CO
# 4          [ces.edu.co]             CO
#
#                                                 name
# 0                  Universidad Autónoma de Manizales
# 1                           Universidad Bellas Artes
# 2                           Conservatorio del Tolima
# 3  Colegio de Estudios Superiores de Administraci...
# 4                                    Universidad CES

# %%
#ultimas 10 filas
df_uni.tail(10)
# Out:
#     state-province   country                             web_pages  \
# 93            None  Colombia           [http://www.usbmed.edu.co/]
# 94            None  Colombia  [http://www.usergioarboleda.edu.co/]
# 95            None  Colombia             [http://www.usta.edu.co/]
# 96            None  Colombia        [http://www.usurcolombia.com/]
# 97            None  Colombia           [http://www.utadeo.edu.co/]
# 98            None  Colombia             [http://www.utch.edu.co/]
# 99            None  Colombia               [http://www.ut.edu.co/]
# 100           None  Colombia              [http://www.utp.edu.co/]
# 101           None  Colombia      [https://universidadean.edu.co/]
# 102           None  Colombia        [https://www.colmayor.edu.co/]
#
#                       domains alpha_two_code  \
# 93            [usbmed.edu.co]             CO
# 94   [usergioarboleda.edu.co]             CO
# 95              [usta.edu.co]             CO
# ...

# %%
#3 filas aleatoreas
df_uni.sample(3)
# Out:
#    state-province   country                      web_pages            domains  \
# 77           None  Colombia   [http://www.unincca.edu.co/]   [unincca.edu.co]
# 90           None  Colombia  [http://www.urosario.edu.co/]  [urosario.edu.co]
# 76           None  Colombia  [http://www.unimetro.edu.co/]  [unimetro.edu.co]
#
#    alpha_two_code                           name
# 77             CO  Universidad INCCA de Colombia
# 90             CO        Universidad del Rosario
# 76             CO      Universidad Metropolitana

# %%
# de la fila 2 a la 5 y la columna 2
df_uni.iloc[1:5, 1]
# Out:
# 1    Colombia
# 2    Colombia
# 3    Colombia
# 4    Colombia
# Name: country, dtype: object

# %%
#cuantas filas hay?
len(df_uni)
# Out:
# 103

# %%
#cuantas filas y columnas hay?
df_uni.shape
# Out:
# (103, 6)

# %%
#cual es el nombre de las columnas
df_uni.columns
# Out:
# Index(['state-province', 'country', 'web_pages', 'domains', 'alpha_two_code',
#        'name'],
#       dtype='object')

# %%
#tipo de dato de las columnas
df_uni.dtypes
# Out:
# state-province    object
# country           object
# web_pages         object
# domains           object
# alpha_two_code    object
# name              object
# dtype: object

# %%
#informacion del dataset
df_uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state-province  0 non-null      object
#  1   country         103 non-null    object
#  2   web_pages       103 non-null    object
#  3   domains         103 non-null    object
#  4   alpha_two_code  103 non-null    object
#  5   name            103 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB
